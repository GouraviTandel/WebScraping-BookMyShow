# %%
# Jovian Commit Essentials
# Please retain and execute this cell without modifying the contents for `jovian.commit` to work
# !pip install jovian --upgrade -q
import jovian
jovian.set_project('web-scraping-bookmyshow')
jovian.set_colab_id('1vu2frlBjFeboZujBe9QPCOnVX0WN5M1t')

# %% [markdown]
# # **Scraping BookMyShow Movie Data using Python & Selenium**
#
# ***Web scraping*** is an automatic method to obtain large amounts of data from websites.[Read more](https://en.wikipedia.org/wiki/Web_scraping)
#
# ![](https://i.imgur.com/Yfs3KKh.jpg)
#
# ***BookMyShow*** is India's largest entertainment ticketing website. Headquartered in Mumbai, it is the only destination for movie and non-movie options like events, plays and sports. Apart from movies, BookMyShow has ticketed for more than 300 live large format events and sport events such as ICL, city Marathons, etc.
# For Booking, [Go To](https://in.bookmyshow.com/explore/home/)
#
# In this project, we'll retrive information from the [BookMyShow](https://in.bookmyshow.com/explore/home/) using Web Scraping.
#
# We'll use the Python library [Selenium](https://selenium-python.readthedocs.io/) to scrape data from the website.
#
# Here's an outline of the setps we'll follow:
#
# 1. Install and import all the libraries to get the data from the WebElement.
# 2. Generate the list of Popular Cities and Other Cities using `find_element` method.
# 3. Extract the list of Movies, Censor Ratings, Language, Booking URL and convert it to DataFrame for 3 Popular Cities..
# 4. Extract additional details such as Hearts, User Ratings for 3 Movies.
# 5. Extract Theatre details for the current day on the basis of Booking URL for 3 Hindi Movies.
# 6. Merge the DataFrames to generate the Combined data with all the details.
# 7. Save the extracted information to a CSV file
#
# By the end of the project, we'll create a CSV file in the following format:
#
# ```
# City,Movie Name,language,Cencor Rating,Hearts,Ratings Received,Theatre Name,Booking Url
# MUMBAI,The Kashmir Files,Hindi,A,98%,199.3K,ratings,Cinepolis: Fun Republic Mall, Andheri (W),https://in.bookmyshow.com/mumbai/movies/the-kashmir-files/ET00110845
# ...
# ```

# %% [markdown]
# ### **How to Run the Code**
#
# You can execute the code by using the "Run" button at the top of this page and selecting "Run on Colab". You can make changes and save your own version of the notebook to [Jovian](https://www.jovianai) by executing the following cells:

# %% [markdown]
# ### **Install and import all the libraries to get the data from the WebElement**
#
# We will use `jovian` library to run this notebook on Google Colab

# %%
# !pip install jovian --upgrade --quiet

# %% [markdown]
# We will use `Selenium` and `kora` library to get the required WebDriverElements
#
# We will use `pandas` to convert the data into DataFrames and Save it to .CSV file.
#
# We will use `time` to provide Sleep time to the Web Site.
#
# The library can be installed by using `pip`.

# %%
# !pip install requests --upgrade --quiet
# !pip install kora -q --quiet
from kora.selenium import wd
from selenium.webdriver.common.by import By
#import os
import pandas as pd
import time
# Out:
#      |████████████████████████████████| 63 kB 1.4 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
#      |████████████████████████████████| 57 kB 3.4 MB/s
#      |████████████████████████████████| 55 kB 3.8 MB/s

# %% [markdown]
# Now we have installed and imported all the required libraries

# %%
BMS_url="https://in.bookmyshow.com/explore/home"

# %% [markdown]
# ### **Generate the list of Popular Cities and Other Cities using `find_element` method.**
#
# We will generate a list of all the **Popular Cities** and **Other Cities** provided on the BookMyShow website.
#
# ![](https://imgur.com/Lc9hx4d.jpg)

# %% [markdown]
# Let's select Mumbai as the Default city to open the web page

# %%
wd.get(BMS_url+"/Mumbai")

# %% [markdown]
# `.get()` launches a new browser and opens the given URL in your Webdriver. It simply takes the string as your specified URL and opens it for testing purposes.
#
# After the web browser is launched, the next step is to access the list of Cities by clicking below highlighted button.
#
# ![](https://imgur.com/n96E3uA.jpg)
#
# The highlighted button can be clicked by using `.click()` on the WebElement.

# %% [markdown]
# ## Geting the class name(html element) to create WebElement.
#
# To get the class name, right click on the button to be clicked and select **Inspect**
#
# ![](https://imgur.com/5zkffTL.jpg)
#
# Get the class name and create a WebElement using the `.find_Element_by_class_name()` function.
#
# Selenium **Find Element** command takes in the By object as the parameter and returns an object of type list WebElement in Selenium.

# %%
cities=wd.find_element_by_class_name("sc-kaNhvL.jlISnX.ellipsis") #Click on the Select region options
cities.click()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   """Entry point for launching an IPython kernel.

# %%
time.sleep(2)

# %% [markdown]
# `.sleep()` will give sleep time of 2s for the page to load and avoid blank WebElements

# %%
Cities_data=wd.find_elements(By.XPATH,'//span[@class="sc-iuDHTM uqCMs"]')
Other_Cities_tag=wd.find_element_by_class_name("sc-jxGEyO.fQHEXW") #Click on other Cities
Other_Cities_tag.click()
Other_Cities_data=wd.find_elements(By.XPATH,'//div[@class="sc-cqPOvA fmMura"]')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead

# %% [markdown]
# Get the WebElements for Popular Cities. Here, class name for span tag is passed to the `XPATH`.
#
# XPath is a technique in Selenium to navigate through the HTML structure of a page

# %%
print(Cities_data)
# Out:
# [<span class="sc-iuDHTM uqCMs">Mumbai</span>, <span class="sc-iuDHTM uqCMs">NCR</span>, <span class="sc-iuDHTM uqCMs">Bengaluru</span>, <span class="sc-iuDHTM uqCMs">Hyderabad</span>, <span class="sc-iuDHTM uqCMs">Ahmedabad</span>, <span class="sc-iuDHTM uqCMs">Chandigarh</span>, <span class="sc-iuDHTM uqCMs">Chennai</span>, <span class="sc-iuDHTM uqCMs">Pune</span>, <span class="sc-iuDHTM uqCMs">Kolkata</span>, <span class="sc-iuDHTM uqCMs">Kochi</span>]

# %%
type(Cities_data)
# Out:
# list

# %%
Cities=[]
for e in Cities_data:
  Cities.append(e.get_attribute('innerHTML'))

# %% [markdown]
# Now, to extract the Popular Cities name, we need to loop over the list that contains WebElement and use the `.get_attribute()` passing `innerHTML`

# %%
print(Cities)
# Out:
# ['Mumbai', 'NCR', 'Bengaluru', 'Hyderabad', 'Ahmedabad', 'Chandigarh', 'Chennai', 'Pune', 'Kolkata', 'Kochi']

# %% [markdown]
# Now, the for loop is converted to a function

# %%
def loop(list_data):
  List_name=[]
  for e in list_data:
    List_name.append(e.get_attribute('innerHTML'))
  return List_name

# %% [markdown]
# Calling the **loop** funtion

# %%
popular_Cities=loop(Cities_data)
Other_Cities=loop(Other_Cities_data)
print(popular_Cities)
print(Other_Cities)
# Out:
# ['Mumbai', 'NCR', 'Bengaluru', 'Hyderabad', 'Chandigarh', 'Ahmedabad', 'Chennai', 'Pune', 'Kolkata', 'Kochi']
# ['Aalo', 'Abohar', 'Abu Road', 'Achampet', 'Acharapakkam', 'Addanki', 'Adilabad', 'Adimali', 'Adipur', 'Adoni', 'Agar Malwa', 'Agartala', 'Agiripalli', 'Agra', 'Ahmedgarh', 'Ahmednagar', 'Ahore', 'Aizawl', 'Ajmer', 'Akaltara', 'Akbarpur', 'Akividu', 'Akluj', 'Akola', 'Akot', 'Alakode', 'Alangudi', 'Alangulam', 'Alappuzha', 'Alathur', 'Alibaug', 'Aligarh', 'Almora', 'Alsisar (Rajasthan)', 'Alur', 'Alwar', 'Amadalavalasa', 'Amalapuram', 'Amalner', 'Amangal', 'Amaravathi', 'Ambajogai', 'Ambala', 'Ambikapur', 'Ambur', 'Amgaon', 'Amravati', 'Amreli', 'Amritsar', 'Amroha', 'Anaikatti', 'Anakapalle', 'Anand', 'Anandapur', 'Anantapalli', 'Anantapur', 'Anaparthi', 'Anchal', 'Andaman And Nicobar', 'Anekal', 'Angadipuram', 'Angamaly', 'Angara', 'Angul', 'Anjad', 'Anjar', 'Anklav', 'Ankleshwar', 'Annigeri', 'Arakkonam', 'Arambagh', 'Arambol', 'Aranthangi', 'Aravakurichi', 'Ariyalur', 'Arkalgud', 'Armoor', 'Arni', 'Arsikere', 'Aruppukottai', 'Asansol', 'Ashoknagar', 'Ashoknagar (West Bengal)', 'Ashta', 'Ashta (Maharashtra)', 'Asika', 'Aswaraopeta', 'Athagarh', 'Athani', 'Atmakur (Nellore)', 'Atpadi', 'Attili', 'Attingal', 'Attur', 'Aurangabad', 'Aurangabad (Bihar)', 'Aurangabad (West Bengal)', 'Auroville', 'Aushapur', 'Avinashi', 'Azamgarh', 'B. Kothakota', 'Badami', 'Badaun', 'Baddi', 'Badhra', 'Badnagar', 'Badnawar', 'Bagaha', 'Bagalkot', 'Bagbahara', 'Bagepalli', 'Bagha Purana', 'Baghmari', 'Bagnan', 'Bagru', 'Bahadurgarh', 'Bahraich', 'Baidyabati', 'Baihar', 'Baijnath', 'Baikunthpur', 'Baindur', 'Bakhrahat', 'Balaghat', 'Balangir', 'Balasore', 'Balijipeta', 'Balod', 'Baloda Bazar', 'Balotra', 'Balrampur', 'Balurghat', 'Banaskantha', 'Banga', 'Bangaon', 'Bangarpet', 'Bangarupalem', 'Banki', 'Banswada', 'Banswara', 'Bantumilli', 'Bapatla', 'Barabanki', 'Baramati', 'Baran', 'Barasat', 'Baraut', 'Bardoli', 'Bareilly', 'Bareja', 'Bargarh', 'Barharwa', 'Barhi', 'Baripada', 'Barmer', 'Barnala', 'Barrackpore', 'Barshi', 'Baruipur', 'Barwadih', 'Barwaha', 'Barwani', 'Basirhat', 'Basna', 'Basti', 'Bathinda', 'Batlagundu', 'Bavla', 'Bayad', 'Bayana', 'Beawar', 'Beed', 'Beguniapada', 'Belagavi (Belgaum)', 'Belakavadi', 'Belghoria', 'Bellampalli', 'Bellary', 'Belur', 'Bemetara', 'Berachampa', 'Berhampore', 'Berhampur', 'Bestavaripeta', 'Betalbatim', 'Bethamcherla', 'Betul', 'Bhadrachalam', 'Bhadrak', 'Bhadravati', 'Bhainsa', 'Bhandara', 'Bharamasagara', 'Bharatpur', 'Bharuch', 'Bhatapara', 'Bhatkal', 'Bhattiprolu', 'Bhavani', 'Bhavnagar', 'Bhawanipatna', 'Bheemgal', 'Bhilai', 'Bhilwara', 'Bhimadole', 'Bhimavaram', 'Bhiwadi', 'Bhiwani', 'Bhongir', 'Bhopal', 'Bhubaneswar', 'Bhuj', 'Bhuntar', 'Bhupalpalle', 'Bhusawal', 'Bhutan', 'Bhuvanagiri', 'Biaora', 'Bibinagar', 'Bichkunda', 'Bidadi', 'Bidar', 'Bihar Sharif', 'Bihpuria', 'Bijnor', 'Bijoynagar', 'Bikaner', 'Bikramganj', 'Bilara', 'Bilaspur', 'Bilaspur (Himachal Pradesh)', 'Bilgi', 'Bilimora', 'Biraul', 'Bishnupur', 'Bishrampur', 'Biswanath Chariali', 'Bobbili', 'Bodhan', 'Bodinayakanur', 'Boisar', 'Bokaro', 'Bolpur', 'Bomdila', 'Bommidi', 'Bonakal', 'Bongaigaon', 'Bongaon', 'Borsad', 'Brahmapur', 'Brahmapuri', 'Brajrajnagar', 'Buchireddypalem', 'Budhlada', 'Bulandshahr', 'Buldana', 'Bundu', 'Burdwan', 'Burhanpur', 'Byadagi', 'Byadgi', 'Byasanagar', 'Canning', 'Chagallu', 'Chalisgaon', 'Challakere', 'Challapalli', 'Chamarajnagar', 'Chamba', 'Chamoli', 'Champa', 'Champahati', 'Chanchal', 'Chandannagar', 'Chandausi', 'Chandpur Siau', 'Chandrakona', 'Chandrapur', 'Chandur', 'Changanassery', 'Changaramkulam', 'Channagiri', 'Channapatna', 'Channarayapatna', 'Chanpatia', 'Charkhi Dadri', 'Chaygaon', 'Cheeka', 'Cheepurupalli', 'Chelpur', 'Chendrapinni', 'Chengalpattu', 'Chengannur', 'Chennur', 'Chenthrapini', 'Cherial', 'Cherla', 'Cherpulassery', 'Cherrapunji', 'Cherthala', 'Chevella', 'Cheyyar', 'Cheyyur', 'Chhatarpur', 'Chhibramau', 'Chhindwara', 'Chickmagaluru', 'Chidambaram', 'Chikhli', 'Chikkaballapur', 'Chikodi', 'Chilakaluripet', 'Chinnalapatti', 'Chinnamanur', 'Chinsurah', 'Chintalapudi', 'Chinturu ...

# %% [markdown]
# ### **Extract the list of Movies, Censor Ratings, Language, Booking URL and covert it to DataFrame for 3 Popular Cities.**
#
# After we have the list of Popular Cities, we will perform below steps to get the list of Movies, Censor Ratings, Language, Booking URL.
#
#
# *   Open the Website using `.get()`
# *   Click on the **Select Region** button and click on the City Name passed.
# *   Click on the **See all** button to load all the movie names for that City
# *   Use `wd.execute_script("window.scrollTo(0, 10000)")` to scroll down to access the entire page.
# *   Save the WebElement for Movies, Censor Ratings, Language, Booking URL in list
# *   Create a function to convert list WebElements data to List Readable data
#
#
# We will create a function called **populate_dataframe** to populate list WebElement data to a List Readable Data to convert it into a DataFrame.
#
# For the details of 3 Cities, we will use a **For** loop and return a **Dictionary** of the Data

# %%
def populate_dataframe(list_of_movies,Rating_Language,city_name,Booking_URL):
  for i in list_of_movies:
    Movies.append(i.text)
    City.append(city_name)
  for i in range(0,len(Rating_Language)):
    if i % 2==0:
      Rating.append(Rating_Language[i].text)
    else:
      language.append(Rating_Language[i].text)
  for i in range(1,len(Booking_URL)):
    Booking_url.append(Booking_URL[i].get_attribute('href')) 
  Movie_Details={'City': City,"Movie Name":Movies,'Language':language,'Censor Rating':Rating,'Booking Url':Booking_url} 
  return Movie_Details

# %% [markdown]
# **Rating,language-** Rating_Language WebElement has data for Ratings and Language arranged in Alternate manner
#
# **Movie_Booking_url-**`href` attribute of the Booking_url is used to extract the Booking link of the Movies
#
# **City-** city_name is provided as a fixed city name to all the entries under that city
#
# **Movies-** `.text()` is used to get the values of WebElement

# %% [markdown]
# Calling the **populate_dataframe** function and **Creating get_WebElement_Movie** function to get the list containing WebElements

# %%
def get_WebElement_Movie(wd):
  for i in range(0,3):
    wd.get(BMS_url+"/Mumbai")
    cities=wd.find_element_by_class_name("sc-kaNhvL.jlISnX.ellipsis").click() #Click on the Select region options
    time.sleep(2)
    Other_Cities_tag=wd.find_element_by_class_name("sc-jxGEyO.fQHEXW").click()
    emojis_imgs = wd.find_elements_by_xpath('//img[@class="sc-bqjOQT aUKrX"]') #Get the WebElement from img tag 
    city_name=emojis_imgs[i].get_attribute('alt') #Get the City name saved in a list
    datac=emojis_imgs[0].click()
    time.sleep(2)
    See_all=wd.find_element_by_class_name("sc-7o7nez-0.gUjRuq").click() #Click on Sell All
    wd.execute_script("window.scrollTo(0, 10000);") #to Scroll the page down
    time.sleep(5)
    list_of_movies=wd.find_elements_by_class_name("sc-7o7nez-0.bJKnib") #Get movie names
    Rating_Language=wd.find_elements(By.XPATH,"//div[@class='sc-7o7nez-0 kQsZEC']") #Get rating and language
    Booking_URL=wd.find_elements(By.CLASS_NAME,'sc-133848s-11.sc-1ljcxl3-1.eQiiBj') #Get Booking Link
    Movie_Details=populate_dataframe(list_of_movies,Rating_Language,city_name,Booking_URL)
    #Movie_Details={'City': City,"Movie Name":Movies,'Language':language,'Censor Rating':Rating,'Booking Url':Booking_url}
  return Movie_Details

# %% [markdown]
# Calling the **get_WebElement_movie** function

# %%
Movies=[]
Rating=[]
language=[]
Booking_url=[]
City=[]
Movie_Details=get_WebElement_Movie(wd)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   from ipykernel import kernelapp as app

# %%
print(Movie_Details)
# Out:
# {'City': ['MUMBAI', 'MUMBAI', 'MUMBAI', 'MUMBAI', 'MUMBAI', 'MUMBAI', 'MUMBAI', 'MUMBAI', 'MUMBAI', 'MUMBAI', 'MUMBAI', 'MUMBAI', 'MUMBAI', 'MUMBAI', 'NCR', 'NCR', 'NCR', 'NCR', 'NCR', 'NCR', 'NCR', 'NCR', 'NCR', 'NCR', 'NCR', 'NCR', 'NCR', 'NCR', 'BANG', 'BANG', 'BANG', 'BANG', 'BANG', 'BANG', 'BANG', 'BANG', 'BANG', 'BANG', 'BANG', 'BANG', 'BANG', 'BANG'], 'Movie Name': ['RRR', 'The Kashmir Files', 'Bachchhan Paandey ', 'The Batman', 'Gangubai Kathiawadi', 'King Richard', 'Pawankhind', 'Jhund', 'Dear Father', 'Radhe Shyam', 'James', 'Uncharted', 'Pushpa: The Rise - Part 01', 'Dilwale Dulhania Le Jayenge', 'RRR', 'The Kashmir Files', 'Bachchhan Paandey ', 'The Batman', 'Gangubai Kathiawadi', 'King Richard', 'Pawankhind', 'Jhund', 'Dear Father', 'Radhe Shyam', 'James', 'Uncharted', 'Pushpa: The Rise - Part 01', 'Dilwale Dulhania Le Jayenge', 'RRR', 'The Kashmir Files', 'Bachchhan Paandey ', 'The Batman', 'Gangubai Kathiawadi', 'King Richard', 'Pawankhind', 'Jhund', 'Dear Father', 'Radhe Shyam', 'James', 'Uncharted', 'Pushpa: The Rise - Part 01', 'Dilwale Dulhania Le Jayenge'], 'Language': ['Telugu, Hindi, Tamil, Kannada, Malayalam', 'Hindi', 'Hindi', 'English, Hindi, Tamil, Telugu', 'Hindi, Telugu', 'English', 'Marathi', 'Hindi', 'Gujarati', 'Telugu, Tamil, Hindi, Malayalam, Kannada', 'Kannada, Telugu, Tamil, Malayalam, Hindi', 'English, Hindi, Tamil, Telugu', 'Telugu, Tamil, Malayalam, Kannada, Hindi', 'Hindi', 'Telugu, Hindi, Tamil, Kannada, Malayalam', 'Hindi', 'Hindi', 'English, Hindi, Tamil, Telugu', 'Hindi, Telugu', 'English', 'Marathi', 'Hindi', 'Gujarati', 'Telugu, Tamil, Hindi, Malayalam, Kannada', 'Kannada, Telugu, Tamil, Malayalam, Hindi', 'English, Hindi, Tamil, Telugu', 'Telugu, Tamil, Malayalam, Kannada, Hindi', 'Hindi', 'Telugu, Hindi, Tamil, Kannada, Malayalam', 'Hindi', 'Hindi', 'English, Hindi, Tamil, Telugu', 'Hindi, Telugu', 'English', 'Marathi', 'Hindi', 'Gujarati', 'Telugu, Tamil, Hindi, Malayalam, Kannada', 'Kannada, Telugu, Tamil, Malayalam, Hindi', 'English, Hindi, Tamil, Telugu', 'Telugu, Tamil, Malayalam, Kannada, Hindi', 'Hindi'], 'Censor Rating': ['UA', 'A', 'UA', 'UA', 'UA', 'UA', 'UA', 'UA', 'U', 'UA', 'UA', 'UA', 'UA', 'U', 'UA', 'A', 'UA', 'UA', 'UA', 'UA', 'UA', 'UA', 'U', 'UA', 'UA', 'UA', 'UA', 'U', 'UA', 'A', 'UA', 'UA', 'UA', 'UA', 'UA', 'UA', 'U', 'UA', 'UA', 'UA', 'UA', 'U'], 'Booking Url': ['https://in.bookmyshow.com/mumbai/movies/rrr/ET00094579', 'https://in.bookmyshow.com/mumbai/movies/the-kashmir-files/ET00110845', 'https://in.bookmyshow.com/mumbai/movies/bachchhan-paandey/ET00108170', 'https://in.bookmyshow.com/mumbai/movies/the-batman/ET00129624', 'https://in.bookmyshow.com/mumbai/movies/gangubai-kathiawadi/ET00114897', 'https://in.bookmyshow.com/mumbai/movies/king-richard/ET00122565', 'https://in.bookmyshow.com/mumbai/movies/pawankhind/ET00307433', 'https://in.bookmyshow.com/mumbai/movies/jhund/ET00077233', 'https://in.bookmyshow.com/mumbai/movies/dear-father/ET00322308', 'https://in.bookmyshow.com/mumbai/movies/radhe-shyam/ET00135230', 'https://in.bookmyshow.com/mumbai/movies/james/ET00312373', 'https://in.bookmyshow.com/mumbai/movies/uncharted/ET00311712', 'https://in.bookmyshow.com/mumbai/movies/pushpa-the-rise-part-01/ET00129538', 'https://in.bookmyshow.com/mumbai/movies/dilwale-dulhania-le-jayenge/ET00000652', 'https://in.bookmyshow.com/mumbai/movies/rrr/ET00094579', 'https://in.bookmyshow.com/mumbai/movies/the-kashmir-files/ET00110845', 'https://in.bookmyshow.com/mumbai/movies/bachchhan-paandey/ET00108170', 'https://in.bookmyshow.com/mumbai/movies/the-batman/ET00129624', 'https://in.bookmyshow.com/mumbai/movies/gangubai-kathiawadi/ET00114897', 'https://in.bookmyshow.com/mumbai/movies/king-richard/ET00122565', 'https://in.bookmyshow.com/mumbai/movies/pawankhind/ET00307433', 'https://in.bookmyshow.com/mumbai/movies/jhund/ET00077233', 'https://in.bookmyshow.com/mumbai/movies/dear-father/ET00322308', 'https://in.bookmyshow.com/mumbai/movies/radhe-shyam/ET00135230', 'https://in.b ...

# %% [markdown]
# ## **Saving the Dictionary Data to DataFrame**

# %%
Details_df=pd.DataFrame(Movie_Details)
Details_df
# Out:
#       City                   Movie Name  \
# 0   MUMBAI                          RRR
# 1   MUMBAI            The Kashmir Files
# 2   MUMBAI           Bachchhan Paandey
# 3   MUMBAI                   The Batman
# 4   MUMBAI          Gangubai Kathiawadi
# 5   MUMBAI                 King Richard
# 6   MUMBAI                   Pawankhind
# 7   MUMBAI                        Jhund
# 8   MUMBAI                  Dear Father
# 9   MUMBAI                  Radhe Shyam
# 10  MUMBAI                        James
# 11  MUMBAI                    Uncharted
# 12  MUMBAI   Pushpa: The Rise - Part 01
# 13  MUMBAI  Dilwale Dulhania Le Jayenge
# 14     NCR                          RRR
# 15     NCR            The Kashmir Files
# 16     NCR           Bachchhan Paandey
# 17     NCR                   The Batman
# 18     NCR          Gangubai Kathiawadi
# 19     NCR                 King Richard
# 20     NCR                   Pawankhind
# 21     NCR                        Jhund
# 22     NCR                  Dear Father
# 23     NCR                  Radhe Shyam
# 24     NCR                        James
# 25     NCR                    Uncharted
# 26     NCR   Pushpa: The Rise - Part 01
# 27     NCR  Dilwale Dulhania Le Jayenge
# 28    BANG                          RRR
# 29    BANG            The Kashmir Files
# 30    BANG           Bachchhan Paandey
# 31    BANG                   The Batman
# 32    BANG          Gangubai Kathiawadi
# 33    BANG                 King Richard
# 34    BANG                   Pawankhind
# 35    BANG                        Jhund
# 36    BANG                  Dear Father
# 37    BANG                  Radhe Shyam
# 38    BANG                        James
# 39    BANG                    Uncharted
# 40    BANG   Pushpa: The Rise - Part 01
# 41    BANG  Dilwale Dulhania Le Jayenge
#
#                                     Language Censor Rating  \
# 0   Telugu, Hindi, Tamil, Kannada, Malayalam            UA
# 1                                      Hindi             A
# 2                                      Hindi            UA
# 3              English, Hindi, Tamil, Telugu            UA
# 4                              Hindi, Telugu            UA
# 5                                    English            UA
# 6                                    Marathi            UA
# 7                                      Hindi            UA
# 8                                   Gujarati             U
# 9   Telugu, Tamil, Hindi, Malayalam, Kannada            UA
# 10  Kannada, Telugu, Tamil, Malayalam, Hindi            UA
# 11             English, Hindi, Tamil, Telugu            UA
# 12  Telugu, Tamil, Malayalam, Kannada, Hindi            UA
# 13                                     Hindi             U
# 14  Telugu, Hindi, Tamil, Kannada, Malayalam            UA
# 15                                     Hindi             A
# 16                                     Hindi            UA
# 17             English, Hindi, Tamil, Telugu            UA
# 18                             Hindi, Telugu            UA
# 19                                   English            UA
# 20                                   Marathi            UA
# 21                                     Hindi            UA
# 22                                  Gujarati             U
# 23  Telugu, Tamil, Hindi, Malayalam, Kannada            UA
# 24  Kannada, Telugu, Tamil, Malayalam, Hindi            UA
# 25             English, Hindi, Tamil, Telugu            UA
# 26  Telugu, Tamil, Malayalam, Kannada, Hindi            UA
# 27                                     Hindi             U
# 28  Telugu, Hindi, Tamil, Kannada, Malayalam            UA
# 29                                     Hindi             A
# 30                                     Hindi            UA
# 31             English, Hindi, Tamil, Telugu            UA
# 32                             Hindi, Telugu            UA
# 33                                   English            UA
# 34                                   Marathi            UA
# 35                                     Hindi            UA
# 36                                  Gujarati             U
# 37  Telugu, Tamil, Hindi, Malayalam, Kannada            UA
# 38  Kannada, Telugu, Tamil, Malayalam, Hindi            UA
# 39             English, Hindi, Tamil, Telugu            UA
# 40  Telugu, Tamil, Malayalam, Kannada, Hindi            UA
# 41                                     Hindi             U
#
#                                           Booking Url
# 0   https://in.bookmyshow.com/mumbai/movies/rrr/ET...
# 1   https://in.bookmyshow.com/mumbai/movies/the-ka...
# 2   https://in.bookmyshow.com/mumbai/movies/bachch...
# 3   https://in.bookmyshow.com/mumbai/movies/the-ba...
# 4   https://in.bookmyshow.com/mumbai/movies/gangub...
# 5   https://in.bookmyshow.com/mumbai/movies/king-r...
# 6   https://in.bookmyshow.com/mumbai/movies/pawank...
# 7   https://in.bookmyshow.com/mumbai/movies/jhund/...
# 8   https://in.bookmyshow.com/mumbai/movies/dear-f...
# 9   https://in.bookmyshow.com/mumbai/movies/radhe-...
# 10  https://in.bookmyshow.com/mumbai/movies/james/...
# 11  https://in.bookmyshow.com/mumbai/movies/unchar...
# 12  https://in.bookmyshow.com/mumbai/movies/pushpa...
# 13  https://in.bookmyshow.com/mumbai/movies/dilwal...
# 14  https://in.bookmyshow.com/mumbai/movies/rrr/ET...
# 15  https://in.bookmyshow.com/mumbai/movies/the-ka...
# 16  https://in.bookmyshow.com/mumbai/movies/bachch...
# 17  https://in.bookmyshow.com/mumbai/movies/the-ba...
# 18  https://in.bookmyshow.com/mumbai/movies/gangub...
# 19  https://in.bookmyshow.com/mumbai/movies/king-r...
# 20  https://in.bookmyshow.com/mumbai/movies/pawank...
# 21  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 22  https://in.bookmyshow.com/mumbai/movies/dear-f...
# 23  https://in.bookmyshow.com/mumbai/movies/radhe-...
# 24  https://in.bookmyshow.com/mumbai/movies/james/...
# 25  https://in.bookmyshow.com/mumbai/movies/unchar...
# 26  https://in.bookmyshow.com/mumbai/movies/pushpa...
# 27  https://in.bookmyshow.com/mumbai/movies/dilwal...
# 28  https://in.bookmyshow.com/mumbai/movies/rrr/ET...
# 29  https://in.bookmyshow.com/mumbai/movies/the-ka...
# 30  https://in.bookmyshow.com/mumbai/movies/bachch...
# 31  https://in.bookmyshow.com/mumbai/movies/the-ba...
# 32  https://in.bookmyshow.com/mumbai/movies/gangub...
# 33  https://in.bookmyshow.com/mumbai/movies/king-r...
# 34  https://in.bookmyshow.com/mumbai/movies/pawank...
# 35  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 36  https://in.bookmyshow.com/mumbai/movies/dear-f...
# 37  https://in.bookmyshow.com/mumbai/movies/radhe-...
# 38  https://in.bookmyshow.com/mumbai/movies/james/...
# 39  https://in.bookmyshow.com/mumbai/movies/unchar...
# 40  https://in.bookmyshow.com/mumbai/movies/pushpa...
# 41  https://in.bookmyshow.com/mumbai/movies/dilwal...

# %% [markdown]
# ## **Extract Additonal details such as Hearts, User Ratings. for 3 Movies**
#
# Now from the DataFrame **Details_df**, we will pick 3 Hindi movies and Extract Hearts Numbers and Users Ratings.
#
# We will perform below steps:
#
# * Filter on the DataFrame **Details_df** for **Hindi** as the language and **MUMBAI** as City.
# * Pick up 3 Booking Url and loop using a `for` loop to extract the Hearts Numbers and Users Ratings
# * Create lists for Hearts Numbers and Users Ratings and covert it into DataFrame
#
# Here, we are limiting the scope of Web Scraping for Hindi Movies in MUMBAI City, as Movies with Multiple languages will have a additional option to select the language which will create additonal loops.

# %% [markdown]
# Filter on the DataFrame **Details_df** for **Hindi** as the language and **MUMBAI** as City

# %%
Movie_List=Details_df[Details_df['Language']=='Hindi']
Movie_List_new=Movie_List[Movie_List['City']=='MUMBAI']
Movie_List_new
# Out:
#       City                   Movie Name Language Censor Rating  \
# 1   MUMBAI            The Kashmir Files    Hindi             A
# 2   MUMBAI           Bachchhan Paandey     Hindi            UA
# 7   MUMBAI                        Jhund    Hindi            UA
# 13  MUMBAI  Dilwale Dulhania Le Jayenge    Hindi             U
#
#                                           Booking Url
# 1   https://in.bookmyshow.com/mumbai/movies/the-ka...
# 2   https://in.bookmyshow.com/mumbai/movies/bachch...
# 7   https://in.bookmyshow.com/mumbai/movies/jhund/...
# 13  https://in.bookmyshow.com/mumbai/movies/dilwal...

# %%
Movie_List_new.reset_index(drop=True, inplace=True)
Movie_List_new
# Out:
#      City                   Movie Name Language Censor Rating  \
# 0  MUMBAI            The Kashmir Files    Hindi             A
# 1  MUMBAI           Bachchhan Paandey     Hindi            UA
# 2  MUMBAI                        Jhund    Hindi            UA
# 3  MUMBAI  Dilwale Dulhania Le Jayenge    Hindi             U
#
#                                          Booking Url
# 0  https://in.bookmyshow.com/mumbai/movies/the-ka...
# 1  https://in.bookmyshow.com/mumbai/movies/bachch...
# 2  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 3  https://in.bookmyshow.com/mumbai/movies/dilwal...

# %% [markdown]
# Reseting the row number of the DataFrame to ensure all the rows numbers have data available

# %% [markdown]
# **Pick up 3 Booking Url and loop over a `for` loop to extract the Hearts Numbers and Users Ratings and Create lists.**

# %% [markdown]
# Create function **get_WebElement_for_Ratings** to fetch Web Elements for Heart Numbers and User Ratings in the form of a Dictionary

# %%
def get_WebElement_for_Ratings():
  wd.get(Movie_List_new['Booking Url'][i])
  time.sleep(5)
  Heart=wd.find_elements_by_class_name("sc-ec6ph5-3.clvawV")[0].text
  rate=wd.find_elements_by_class_name("sc-ec6ph5-4.geTheh")[0].text
  URL_for_Movies.append(Movie_List_new['Booking Url'][i])
  Hearts.append(Heart)
  Ratings_Values.append(rate)
  More_details={'Booking Url':URL_for_Movies,'Hearts':Hearts,"Ratings Received":Ratings_Values}
  return More_details

# %% [markdown]
# Calling the function get_WebElement_for_Ratings() in a for loop

# %%
URL_for_Movies=[]
Hearts=[]
Ratings_Values=[]
for i in range(0,3):
  More_details=get_WebElement_for_Ratings()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   """

# %% [markdown]
# ## **Saving the Dictionary Data to DataFrame**

# %%
More_details_df=pd.DataFrame(More_details)
More_details_df
# Out:
#                                          Booking Url Hearts Ratings Received
# 0  https://in.bookmyshow.com/mumbai/movies/the-ka...    92%   449.8K ratings
# 1  https://in.bookmyshow.com/mumbai/movies/bachch...    71%    38.4K ratings
# 2  https://in.bookmyshow.com/mumbai/movies/jhund/...    87%    29.8K ratings

# %% [markdown]
# ## **Extract Theatre details for the current day on the basis of Booking URL for 3 Hindi Movies in Mumbai.**
#
# Now we will extract the list of Theatres for 3 Movies for the Current Day.
#
# We will perform below steps:
# * From the DataFrame Movies_Details_df, we will navigate to the Booking URL for each movie
# * Click on the **Book** button
# * Create a function to extract the list of Theatre Name for each Movie for current day
# * Convert the list to a dictionary
# * Convert the Dictionary to DataFrame

# %% [markdown]
# **Creating the function WebElement_to_data**

# %%
def WebElement_to_data(venue_name,URL):
  theatre_name=[]
  Booking_URL=[]
  for i in venue_name:
    theatre_name.append(i.text)
    Booking_URL.append(URL)
  return theatre_name,Booking_URL

# %% [markdown]
# **Creating the function get_theatre**

# %%
def get_theatre(wd,URL):
  wd.get(URL)
  Book_tickets=wd.find_elements(By.XPATH,'//div[@class="sc-1vmod7e-2 cgQNto"]') #Book Tickets
  Book_tickets[0].click()
  venue_name=wd.find_elements(By.XPATH,'//a[@class="__venue-name"]') #Get WebElement for Venue
  theatre,URL=WebElement_to_data(venue_name,URL)
  return theatre,URL

# %% [markdown]
# Calling **get_theatre** function and save in a Dictionary

# %%
def Venue_Details_list(i):
  print(Movie_List_new['Booking Url'][i])
  venue_list,url_list=get_theatre(wd,Movie_List_new['Booking Url'][i])
  for i in venue_list:
    Venue_name.append(i)
  for i in url_list:
    Movie_URL.append(i)
  Theatre_data={"Booking Url":Movie_URL,"Theatre Name":Venue_name,'City':'MUMBAI'}
  return Theatre_data

# %%
Venue_name=[]
Movie_URL=[]
for i in range(0,3):
  Theatre_data=Venue_Details_list(i)
# Out:
# https://in.bookmyshow.com/mumbai/movies/the-kashmir-files/ET00110845
# https://in.bookmyshow.com/mumbai/movies/bachchhan-paandey/ET00108170
# https://in.bookmyshow.com/mumbai/movies/jhund/ET00077233

# %%
len(Venue_name)
# Out:
# 162

# %% [markdown]
#  **Creating DataFrame for Theatre**

# %%
Theatre_data_df=pd.DataFrame(Theatre_data)
Theatre_data_df
# Out:
#                                            Booking Url  \
# 0    https://in.bookmyshow.com/mumbai/movies/the-ka...
# 1    https://in.bookmyshow.com/mumbai/movies/the-ka...
# 2    https://in.bookmyshow.com/mumbai/movies/the-ka...
# 3    https://in.bookmyshow.com/mumbai/movies/the-ka...
# 4    https://in.bookmyshow.com/mumbai/movies/the-ka...
# ..                                                 ...
# 157  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 158  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 159  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 160  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 161  https://in.bookmyshow.com/mumbai/movies/jhund/...
#
#                                          Theatre Name    City
# 0                 CinemaStar: High Street Mall, Thane  MUMBAI
# 1                      Cinepolis: Viviana Mall, Thane  MUMBAI
# 2    INOX: Korum Mall, Eastern Express Highway, Thane  MUMBAI
# 3               Carnival: Little World Mall, Kharghar  MUMBAI
# 4      Cinepolis: Seawoods Grand Central, Navi Mumbai  MUMBAI
# ..                                                ...     ...
# 157                     Movietime Cubic Mall: Chembur  MUMBAI
# 158                PVR: Market City, Kurla (Premiere)  MUMBAI
# 159                                         PVR: Sion  MUMBAI
# 160                     Cinemax: Eternity Mall, Thane  MUMBAI
# 161                             PVR: Haseen, Bhiwandi  MUMBAI
#
# [162 rows x 3 columns]

# %% [markdown]
# ## **Merge the DataFrames to generate the Combined data with all the details.**
#
# Here, we will merge 3 DataFrames to create the final Dataset.
#
# Below are the steps to be followed:
#
# * merge_data=Merge Details_df with More_details_df(Outer join on **Booking Url**)
# * Final_Dataset-Merge merge_data with Theatre_data_df (Left join on **Booking Url**)

# %%
Theatre_data_df  #theatre Details
More_details_df #Additonal details
Details_df #Movies for 3 Cities
# Out:
#       City                   Movie Name  \
# 0   MUMBAI                          RRR
# 1   MUMBAI            The Kashmir Files
# 2   MUMBAI           Bachchhan Paandey
# 3   MUMBAI                   The Batman
# 4   MUMBAI          Gangubai Kathiawadi
# 5   MUMBAI                 King Richard
# 6   MUMBAI                   Pawankhind
# 7   MUMBAI                        Jhund
# 8   MUMBAI                  Dear Father
# 9   MUMBAI                  Radhe Shyam
# 10  MUMBAI                        James
# 11  MUMBAI                    Uncharted
# 12  MUMBAI   Pushpa: The Rise - Part 01
# 13  MUMBAI  Dilwale Dulhania Le Jayenge
# 14     NCR                          RRR
# 15     NCR            The Kashmir Files
# 16     NCR           Bachchhan Paandey
# 17     NCR                   The Batman
# 18     NCR          Gangubai Kathiawadi
# 19     NCR                 King Richard
# 20     NCR                   Pawankhind
# 21     NCR                        Jhund
# 22     NCR                  Dear Father
# 23     NCR                  Radhe Shyam
# 24     NCR                        James
# 25     NCR                    Uncharted
# 26     NCR   Pushpa: The Rise - Part 01
# 27     NCR  Dilwale Dulhania Le Jayenge
# 28    BANG                          RRR
# 29    BANG            The Kashmir Files
# 30    BANG           Bachchhan Paandey
# 31    BANG                   The Batman
# 32    BANG          Gangubai Kathiawadi
# 33    BANG                 King Richard
# 34    BANG                   Pawankhind
# 35    BANG                        Jhund
# 36    BANG                  Dear Father
# 37    BANG                  Radhe Shyam
# 38    BANG                        James
# 39    BANG                    Uncharted
# 40    BANG   Pushpa: The Rise - Part 01
# 41    BANG  Dilwale Dulhania Le Jayenge
#
#                                     Language Censor Rating  \
# 0   Telugu, Hindi, Tamil, Kannada, Malayalam            UA
# 1                                      Hindi             A
# 2                                      Hindi            UA
# 3              English, Hindi, Tamil, Telugu            UA
# 4                              Hindi, Telugu            UA
# 5                                    English            UA
# 6                                    Marathi            UA
# 7                                      Hindi            UA
# 8                                   Gujarati             U
# 9   Telugu, Tamil, Hindi, Malayalam, Kannada            UA
# 10  Kannada, Telugu, Tamil, Malayalam, Hindi            UA
# 11             English, Hindi, Tamil, Telugu            UA
# 12  Telugu, Tamil, Malayalam, Kannada, Hindi            UA
# 13                                     Hindi             U
# 14  Telugu, Hindi, Tamil, Kannada, Malayalam            UA
# 15                                     Hindi             A
# 16                                     Hindi            UA
# 17             English, Hindi, Tamil, Telugu            UA
# 18                             Hindi, Telugu            UA
# 19                                   English            UA
# 20                                   Marathi            UA
# 21                                     Hindi            UA
# 22                                  Gujarati             U
# 23  Telugu, Tamil, Hindi, Malayalam, Kannada            UA
# 24  Kannada, Telugu, Tamil, Malayalam, Hindi            UA
# 25             English, Hindi, Tamil, Telugu            UA
# 26  Telugu, Tamil, Malayalam, Kannada, Hindi            UA
# 27                                     Hindi             U
# 28  Telugu, Hindi, Tamil, Kannada, Malayalam            UA
# 29                                     Hindi             A
# 30                                     Hindi            UA
# 31             English, Hindi, Tamil, Telugu            UA
# 32                             Hindi, Telugu            UA
# 33                                   English            UA
# 34                                   Marathi            UA
# 35                                     Hindi            UA
# 36                                  Gujarati             U
# 37  Telugu, Tamil, Hindi, Malayalam, Kannada            UA
# 38  Kannada, Telugu, Tamil, Malayalam, Hindi            UA
# 39             English, Hindi, Tamil, Telugu            UA
# 40  Telugu, Tamil, Malayalam, Kannada, Hindi            UA
# 41                                     Hindi             U
#
#                                           Booking Url
# 0   https://in.bookmyshow.com/mumbai/movies/rrr/ET...
# 1   https://in.bookmyshow.com/mumbai/movies/the-ka...
# 2   https://in.bookmyshow.com/mumbai/movies/bachch...
# 3   https://in.bookmyshow.com/mumbai/movies/the-ba...
# 4   https://in.bookmyshow.com/mumbai/movies/gangub...
# 5   https://in.bookmyshow.com/mumbai/movies/king-r...
# 6   https://in.bookmyshow.com/mumbai/movies/pawank...
# 7   https://in.bookmyshow.com/mumbai/movies/jhund/...
# 8   https://in.bookmyshow.com/mumbai/movies/dear-f...
# 9   https://in.bookmyshow.com/mumbai/movies/radhe-...
# 10  https://in.bookmyshow.com/mumbai/movies/james/...
# 11  https://in.bookmyshow.com/mumbai/movies/unchar...
# 12  https://in.bookmyshow.com/mumbai/movies/pushpa...
# 13  https://in.bookmyshow.com/mumbai/movies/dilwal...
# 14  https://in.bookmyshow.com/mumbai/movies/rrr/ET...
# 15  https://in.bookmyshow.com/mumbai/movies/the-ka...
# 16  https://in.bookmyshow.com/mumbai/movies/bachch...
# 17  https://in.bookmyshow.com/mumbai/movies/the-ba...
# 18  https://in.bookmyshow.com/mumbai/movies/gangub...
# 19  https://in.bookmyshow.com/mumbai/movies/king-r...
# 20  https://in.bookmyshow.com/mumbai/movies/pawank...
# 21  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 22  https://in.bookmyshow.com/mumbai/movies/dear-f...
# 23  https://in.bookmyshow.com/mumbai/movies/radhe-...
# 24  https://in.bookmyshow.com/mumbai/movies/james/...
# 25  https://in.bookmyshow.com/mumbai/movies/unchar...
# 26  https://in.bookmyshow.com/mumbai/movies/pushpa...
# 27  https://in.bookmyshow.com/mumbai/movies/dilwal...
# 28  https://in.bookmyshow.com/mumbai/movies/rrr/ET...
# 29  https://in.bookmyshow.com/mumbai/movies/the-ka...
# 30  https://in.bookmyshow.com/mumbai/movies/bachch...
# 31  https://in.bookmyshow.com/mumbai/movies/the-ba...
# 32  https://in.bookmyshow.com/mumbai/movies/gangub...
# 33  https://in.bookmyshow.com/mumbai/movies/king-r...
# 34  https://in.bookmyshow.com/mumbai/movies/pawank...
# 35  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 36  https://in.bookmyshow.com/mumbai/movies/dear-f...
# 37  https://in.bookmyshow.com/mumbai/movies/radhe-...
# 38  https://in.bookmyshow.com/mumbai/movies/james/...
# 39  https://in.bookmyshow.com/mumbai/movies/unchar...
# 40  https://in.bookmyshow.com/mumbai/movies/pushpa...
# 41  https://in.bookmyshow.com/mumbai/movies/dilwal...

# %%
merged_data=pd.merge(Details_df,More_details_df,on='Booking Url',how='outer')
merged_data
# Out:
#       City                   Movie Name  \
# 0   MUMBAI                          RRR
# 1      NCR                          RRR
# 2     BANG                          RRR
# 3   MUMBAI            The Kashmir Files
# 4      NCR            The Kashmir Files
# 5     BANG            The Kashmir Files
# 6   MUMBAI           Bachchhan Paandey
# 7      NCR           Bachchhan Paandey
# 8     BANG           Bachchhan Paandey
# 9   MUMBAI                   The Batman
# 10     NCR                   The Batman
# 11    BANG                   The Batman
# 12  MUMBAI          Gangubai Kathiawadi
# 13     NCR          Gangubai Kathiawadi
# 14    BANG          Gangubai Kathiawadi
# 15  MUMBAI                 King Richard
# 16     NCR                 King Richard
# 17    BANG                 King Richard
# 18  MUMBAI                   Pawankhind
# 19     NCR                   Pawankhind
# 20    BANG                   Pawankhind
# 21  MUMBAI                        Jhund
# 22     NCR                        Jhund
# 23    BANG                        Jhund
# 24  MUMBAI                  Dear Father
# 25     NCR                  Dear Father
# 26    BANG                  Dear Father
# 27  MUMBAI                  Radhe Shyam
# 28     NCR                  Radhe Shyam
# 29    BANG                  Radhe Shyam
# 30  MUMBAI                        James
# 31     NCR                        James
# 32    BANG                        James
# 33  MUMBAI                    Uncharted
# 34     NCR                    Uncharted
# 35    BANG                    Uncharted
# 36  MUMBAI   Pushpa: The Rise - Part 01
# 37     NCR   Pushpa: The Rise - Part 01
# 38    BANG   Pushpa: The Rise - Part 01
# 39  MUMBAI  Dilwale Dulhania Le Jayenge
# 40     NCR  Dilwale Dulhania Le Jayenge
# 41    BANG  Dilwale Dulhania Le Jayenge
#
#                                     Language Censor Rating  \
# 0   Telugu, Hindi, Tamil, Kannada, Malayalam            UA
# 1   Telugu, Hindi, Tamil, Kannada, Malayalam            UA
# 2   Telugu, Hindi, Tamil, Kannada, Malayalam            UA
# 3                                      Hindi             A
# 4                                      Hindi             A
# 5                                      Hindi             A
# 6                                      Hindi            UA
# 7                                      Hindi            UA
# 8                                      Hindi            UA
# 9              English, Hindi, Tamil, Telugu            UA
# 10             English, Hindi, Tamil, Telugu            UA
# 11             English, Hindi, Tamil, Telugu            UA
# 12                             Hindi, Telugu            UA
# 13                             Hindi, Telugu            UA
# 14                             Hindi, Telugu            UA
# 15                                   English            UA
# 16                                   English            UA
# 17                                   English            UA
# 18                                   Marathi            UA
# 19                                   Marathi            UA
# 20                                   Marathi            UA
# 21                                     Hindi            UA
# 22                                     Hindi            UA
# 23                                     Hindi            UA
# 24                                  Gujarati             U
# 25                                  Gujarati             U
# 26                                  Gujarati             U
# 27  Telugu, Tamil, Hindi, Malayalam, Kannada            UA
# 28  Telugu, Tamil, Hindi, Malayalam, Kannada            UA
# 29  Telugu, Tamil, Hindi, Malayalam, Kannada            UA
# 30  Kannada, Telugu, Tamil, Malayalam, Hindi            UA
# 31  Kannada, Telugu, Tamil, Malayalam, Hindi            UA
# 32  Kannada, Telugu, Tamil, Malayalam, Hindi            UA
# 33             English, Hindi, Tamil, Telugu            UA
# 34             English, Hindi, Tamil, Telugu            UA
# 35             English, Hindi, Tamil, Telugu            UA
# 36  Telugu, Tamil, Malayalam, Kannada, Hindi            UA
# 37  Telugu, Tamil, Malayalam, Kannada, Hindi            UA
# 38  Telugu, Tamil, Malayalam, Kannada, Hindi            UA
# 39                                     Hindi             U
# 40                                     Hindi             U
# 41                                     Hindi             U
#
#                                           Booking Url Hearts Ratings Received
# 0   https://in.bookmyshow.com/mumbai/movies/rrr/ET...    NaN              NaN
# 1   https://in.bookmyshow.com/mumbai/movies/rrr/ET...    NaN              NaN
# 2   https://in.bookmyshow.com/mumbai/movies/rrr/ET...    NaN              NaN
# 3   https://in.bookmyshow.com/mumbai/movies/the-ka...    92%   449.8K ratings
# 4   https://in.bookmyshow.com/mumbai/movies/the-ka...    92%   449.8K ratings
# 5   https://in.bookmyshow.com/mumbai/movies/the-ka...    92%   449.8K ratings
# 6   https://in.bookmyshow.com/mumbai/movies/bachch...    71%    38.4K ratings
# 7   https://in.bookmyshow.com/mumbai/movies/bachch...    71%    38.4K ratings
# 8   https://in.bookmyshow.com/mumbai/movies/bachch...    71%    38.4K ratings
# 9   https://in.bookmyshow.com/mumbai/movies/the-ba...    NaN              NaN
# 10  https://in.bookmyshow.com/mumbai/movies/the-ba...    NaN              NaN
# 11  https://in.bookmyshow.com/mumbai/movies/the-ba...    NaN              NaN
# 12  https://in.bookmyshow.com/mumbai/movies/gangub...    NaN              NaN
# 13  https://in.bookmyshow.com/mumbai/movies/gangub...    NaN              NaN
# 14  https://in.bookmyshow.com/mumbai/movies/gangub...    NaN              NaN
# 15  https://in.bookmyshow.com/mumbai/movies/king-r...    NaN              NaN
# 16  https://in.bookmyshow.com/mumbai/movies/king-r...    NaN              NaN
# 17  https://in.bookmyshow.com/mumbai/movies/king-r...    NaN              NaN
# 18  https://in.bookmyshow.com/mumbai/movies/pawank...    NaN              NaN
# 19  https://in.bookmyshow.com/mumbai/movies/pawank...    NaN              NaN
# 20  https://in.bookmyshow.com/mumbai/movies/pawank...    NaN              NaN
# 21  https://in.bookmyshow.com/mumbai/movies/jhund/...    87%    29.8K ratings
# 22  https://in.bookmyshow.com/mumbai/movies/jhund/...    87%    29.8K ratings
# 23  https://in.bookmyshow.com/mumbai/movies/jhund/...    87%    29.8K ratings
# 24  https://in.bookmyshow.com/mumbai/movies/dear-f...    NaN              NaN
# 25  https://in.bookmyshow.com/mumbai/movies/dear-f...    NaN              NaN
# 26  https://in.bookmyshow.com/mumbai/movies/dear-f...    NaN              NaN
# 27  https://in.bookmyshow.com/mumbai/movies/radhe-...    NaN              NaN
# 28  https://in.bookmyshow.com/mumbai/movies/radhe-...    NaN              NaN
# 29  https://in.bookmyshow.com/mumbai/movies/radhe-...    NaN              NaN
# 30  https://in.bookmyshow.com/mumbai/movies/james/...    NaN              NaN
# 31  https://in.bookmyshow.com/mumbai/movies/james/...    NaN              NaN
# 32  https://in.bookmyshow.com/mumbai/movies/james/...    NaN              NaN
# 33  https://in.bookmyshow.com/mumbai/movies/unchar...    NaN              NaN
# 34  https://in.bookmyshow.com/mumbai/movies/unchar...    NaN              NaN
# 35  https://in.bookmyshow.com/mumbai/movies/unchar...    NaN              NaN
# 36  https://in.bookmyshow.com/mumbai/movies/pushpa...    NaN              NaN
# 37  https://in.bookmyshow.com/mumbai/movies/pushpa...    NaN              NaN
# 38  https://in.bookmyshow.com/mumbai/movies/pushpa...    NaN              NaN
# 39  https://in.bookmyshow.com/mumbai/movies/dilwal...    NaN              NaN
# 40  https://in.bookmyshow.com/mumbai/movies/dilwal...    NaN              NaN
# 41  https://in.bookmyshow.com/mumbai/movies/dilwal...    NaN              NaN

# %%
Movie_and_theatre=pd.merge(Theatre_data_df,merged_data,on=['Booking Url','City'],how='left')

# %% [markdown]
# ## **Arrange the Sequence of Columns**

# %%
Movie_and_theatre = Movie_and_theatre[['City', 'Movie Name', 'Language', 'Censor Rating','Hearts','Ratings Received','Theatre Name','Booking Url']]
Movie_and_theatre
# Out:
#        City         Movie Name Language Censor Rating Hearts Ratings Received  \
# 0    MUMBAI  The Kashmir Files    Hindi             A    92%   449.8K ratings
# 1    MUMBAI  The Kashmir Files    Hindi             A    92%   449.8K ratings
# 2    MUMBAI  The Kashmir Files    Hindi             A    92%   449.8K ratings
# 3    MUMBAI  The Kashmir Files    Hindi             A    92%   449.8K ratings
# 4    MUMBAI  The Kashmir Files    Hindi             A    92%   449.8K ratings
# ..      ...                ...      ...           ...    ...              ...
# 157  MUMBAI              Jhund    Hindi            UA    87%    29.8K ratings
# 158  MUMBAI              Jhund    Hindi            UA    87%    29.8K ratings
# 159  MUMBAI              Jhund    Hindi            UA    87%    29.8K ratings
# 160  MUMBAI              Jhund    Hindi            UA    87%    29.8K ratings
# 161  MUMBAI              Jhund    Hindi            UA    87%    29.8K ratings
#
#                                          Theatre Name  \
# 0                 CinemaStar: High Street Mall, Thane
# 1                      Cinepolis: Viviana Mall, Thane
# 2    INOX: Korum Mall, Eastern Express Highway, Thane
# 3               Carnival: Little World Mall, Kharghar
# 4      Cinepolis: Seawoods Grand Central, Navi Mumbai
# ..                                                ...
# 157                     Movietime Cubic Mall: Chembur
# 158                PVR: Market City, Kurla (Premiere)
# 159                                         PVR: Sion
# 160                     Cinemax: Eternity Mall, Thane
# 161                             PVR: Haseen, Bhiwandi
#
#                                            Booking Url
# 0    https://in.bookmyshow.com/mumbai/movies/the-ka...
# 1    https://in.bookmyshow.com/mumbai/movies/the-ka...
# 2    https://in.bookmyshow.com/mumbai/movies/the-ka...
# 3    https://in.bookmyshow.com/mumbai/movies/the-ka...
# 4    https://in.bookmyshow.com/mumbai/movies/the-ka...
# ..                                                 ...
# 157  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 158  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 159  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 160  https://in.bookmyshow.com/mumbai/movies/jhund/...
# 161  https://in.bookmyshow.com/mumbai/movies/jhund/...
#
# [162 rows x 8 columns]

# %% [markdown]
# ## **Save the extracted information to a CSV file**
#
# Here we will save and download the DataFrame **Movie_and_theatre** using `.to_csv()` function in Pandas and `files.download()` to download the file.

# %%
from google.colab import files
Movie_and_theatre.to_csv('BookMyShow_Data.csv')
files.download('BookMyShow_Data.csv')

# %% [markdown]
# ## **Future Work**
#
# * We can Fetch the Movie Details for all the Popular Cities and Other Cities.
# * We can Fetch the Movie Details for Movies with Multiple Language
# * We can Fetch timing details for their respetive venue
# * we can Fetch Details of other events such as Stand-ups Comedy, Musical Events etc

# %% [markdown]
# ## **Reference**
#
# * https://en.wikipedia.org/wiki/Web_scraping
# * https://selenium-python.readthedocs.io/
# * https://pandas.pydata.org/docs/
# * https://www.selenium.dev/pt-br/documentation/

# %%
jovian.commit(project="web-scraping-bookmyshow")
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Please enter your API key ( from https://jovian.ai/ ):
# API KEY:

# %%
jovian.commit(files=['BookMyShow_Data.csv'])
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Uploading colab notebook to Jovian...
# [jovian] Uploading additional files...
# Committed successfully! https://jovian.ai/gouravitandel1945/web-scraping-bookmyshow
# 'https://jovian.ai/gouravitandel1945/web-scraping-bookmyshow'
